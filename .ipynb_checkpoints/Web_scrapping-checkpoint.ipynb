# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

final = pd.DataFrame()
for j in range(1,502):
    url='https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={}'.format(j)
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    response = requests.get(url,headers=headers).text
    soup = BeautifulSoup(response,'lxml')
    webpage_xml = soup.find_all('div',class_="companyCardWrapper")
    Name=[]
    Rating=[]
    Reviews = []
    Salary = []
    Interviews = []
    Jobs = []
    Benefits = []

    for i in webpage_xml:
        try:
            Name.append(i.find('h2',class_="companyCardWrapper__companyName").text.strip())
        except:
            Name.append(np.nan)
        try:
            Rating.append(i.find('span',class_="companyCardWrapper__companyRatingValue").text.strip())
        except:
            Rating.append(np.nan)
        try:
            Reviews.append(i.find_all('span',class_="companyCardWrapper__ActionCount")[0].text.strip())
        except:
            Reviews.append(np.nan)
        try:
            Salary.append(i.find_all('span',class_="companyCardWrapper__ActionCount")[1].text.strip())
        except:
            Salary.append(np.nan)
        try:
            Interviews.append(i.find_all('span',class_="companyCardWrapper__ActionCount")[2].text.strip())
        except:
            Interviews.append(np.nan)
        try:
            Jobs.append(i.find_all('span',class_="companyCardWrapper__ActionCount")[3].text.strip())
        except:
            Jobs.append(np.nan)
        try:
            Benefits.append(i.find_all('span',class_="companyCardWrapper__ActionCount")[4].text.strip())
        except:
            Benefits.append(np.nan)
            
    d={'Name':Name,'Rating':Rating,'Reviews':Reviews,'Salary':Salary,'Interviews':Interviews,'Jobs':Jobs,'Benefits':Benefits}
    data=pd.DataFrame(d)
    final=final.append(data,ignore_index=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4480\2639579106.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(data,ignore_index=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4480\2639579106.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(data,ignore_index=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4480\2639579106.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(data,ignore_index=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4480\2639579106.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(data,ignore_index=True)
# ...

# %%
final
# Out:
#                        Name Rating Reviews  Salary Interviews   Jobs Benefits
# 0                       TCS    3.8   73.3k  853.6k       6.2k    924    11.5k
# 1                 Accenture    4.0   46.5k    585k       4.4k  13.1k     7.1k
# 2                 Cognizant    3.9   41.8k  561.3k       3.7k    454     5.8k
# 3                     Wipro    3.8   39.3k  427.3k       3.7k    394       5k
# 4                 Capgemini    3.9   34.1k  416.1k       2.9k    721       4k
# ...                     ...    ...     ...     ...        ...    ...      ...
# 9995  Icreon Communications    3.7      72     660          6     12       11
# 9996   OpenXcell Technolabs    4.2      72     684          5      3       --
# 9997       Reinforced Earth    3.9      72     278          2      4       --
# 9998           Black Turtle    3.6      72     348          2     1k       --
# 9999           Global Group    3.6      72     469          2      1       --
#
# [10000 rows x 7 columns]

# %%
df=pd.DataFrame(final)
columns_to_convert = ['Reviews', 'Salary', 'Interviews', 'Jobs', 'Benefits']
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column].replace('[kK]', '', regex=True), errors='coerce')

# %%
df
# Out:
#                        Name Rating  Reviews  Salary  Interviews   Jobs  \
# 0                       TCS    3.8     73.3   853.6         6.2  924.0
# 1                 Accenture    4.0     46.5   585.0         4.4   13.1
# 2                 Cognizant    3.9     41.8   561.3         3.7  454.0
# 3                     Wipro    3.8     39.3   427.3         3.7  394.0
# 4                 Capgemini    3.9     34.1   416.1         2.9  721.0
# ...                     ...    ...      ...     ...         ...    ...
# 9995  Icreon Communications    3.7     72.0   660.0         6.0   12.0
# 9996   OpenXcell Technolabs    4.2     72.0   684.0         5.0    3.0
# 9997       Reinforced Earth    3.9     72.0   278.0         2.0    4.0
# 9998           Black Turtle    3.6     72.0   348.0         2.0    1.0
# 9999           Global Group    3.6     72.0   469.0         2.0    1.0
#
#       Benefits
# 0         11.5
# 1          7.1
# 2          5.8
# 3          5.0
# 4          4.0
# ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# Name             0
# Rating           0
# Reviews          0
# Salary           1
# Interviews     207
# Jobs          3916
# Benefits        87
# dtype: int64

# %%
df.describe()
# Out:
#             Reviews       Salary   Interviews         Jobs     Benefits
# count  10000.000000  9999.000000  9793.000000  6084.000000  9913.000000
# mean     194.473730   336.449595    20.697764    28.636884    43.044941
# std      176.924449   317.130732    48.496924    67.223437    81.814463
# min        1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       89.000000     2.700000     4.000000     3.000000    11.000000
# 50%      130.000000   339.000000     8.000000     9.000000    18.000000
# 75%      235.250000   589.000000    17.000000    26.000000    38.000000
# max      998.000000   999.000000   979.000000   990.000000   973.000000

# %%
df.duplicated().sum()
# Out:
# 701

# %%
df.drop_duplicates()
# Out:
#                        Name Rating  Reviews  Salary  Interviews   Jobs  \
# 0                       TCS    3.8     73.3   853.6         6.2  924.0
# 1                 Accenture    4.0     46.5   585.0         4.4   13.1
# 2                 Cognizant    3.9     41.8   561.3         3.7  454.0
# 3                     Wipro    3.8     39.3   427.3         3.7  394.0
# 4                 Capgemini    3.9     34.1   416.1         2.9  721.0
# ...                     ...    ...      ...     ...         ...    ...
# 9995  Icreon Communications    3.7     72.0   660.0         6.0   12.0
# 9996   OpenXcell Technolabs    4.2     72.0   684.0         5.0    3.0
# 9997       Reinforced Earth    3.9     72.0   278.0         2.0    4.0
# 9998           Black Turtle    3.6     72.0   348.0         2.0    1.0
# 9999           Global Group    3.6     72.0   469.0         2.0    1.0
#
#       Benefits
# 0         11.5
# 1          7.1
# 2          5.8
# 3          5.0
# 4          4.0
# ...        ...
# ...

# %%
df.to_csv('company.csv')

# %%
company=df

# %%
company
# Out:
#                        Name Rating  Reviews  Salary  Interviews   Jobs  \
# 0                       TCS    3.8     73.3   853.6         6.2  924.0
# 1                 Accenture    4.0     46.5   585.0         4.4   13.1
# 2                 Cognizant    3.9     41.8   561.3         3.7  454.0
# 3                     Wipro    3.8     39.3   427.3         3.7  394.0
# 4                 Capgemini    3.9     34.1   416.1         2.9  721.0
# ...                     ...    ...      ...     ...         ...    ...
# 9995  Icreon Communications    3.7     72.0   660.0         6.0   12.0
# 9996   OpenXcell Technolabs    4.2     72.0   684.0         5.0    3.0
# 9997       Reinforced Earth    3.9     72.0   278.0         2.0    4.0
# 9998           Black Turtle    3.6     72.0   348.0         2.0    1.0
# 9999           Global Group    3.6     72.0   469.0         2.0    1.0
#
#       Benefits
# 0         11.5
# 1          7.1
# 2          5.8
# 3          5.0
# 4          4.0
# ...        ...
# ...
